# %%
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df_av=pd.read_csv("avocado dataset.csv")

# %%
df_av
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0             0.0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1             1.0  20-12-2015          1.35      54876.98   674.28   44638.81
# 2             2.0  13-12-2015          0.93     118220.22   794.70  109149.67
# 3             3.0  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4             4.0  29-11-2015          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 16463         NaN         NaN           NaN           NaN      NaN        NaN
# 16464         NaN         NaN           NaN           NaN      NaN        NaN
# 16465         NaN         NaN           NaN           NaN      NaN        NaN
# 16466         NaN         NaN           NaN           NaN      NaN        NaN
# 16467         NaN         NaN           NaN           NaN      NaN        NaN
#
# ...

# %%
df_av=df_av.dropna(how='all')
#dropping all columns with null values

# %%
df_av['month'] = pd.DatetimeIndex(df_av['Date']).month

#creating  months and date column separately
# Out:
# <ipython-input-5-742ab4dc5661>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_av['month'] = pd.DatetimeIndex(df_av['Date']).month

# %%
df_av = df_av.loc[:,df_av.apply(pd.Series.nunique) != 1]

# %%
df_av.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0         0.0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1         1.0  20-12-2015          1.35      54876.98   674.28   44638.81
# 2         2.0  13-12-2015          0.93     118220.22   794.70  109149.67
# 3         3.0  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4         4.0  29-11-2015          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags    year  region  \
# 0   48.16     8696.87     8603.62       93.25          0.0  2015.0  Albany
# 1   58.33     9505.56     9408.07       97.49          0.0  2015.0  Albany
# 2  130.50     8145.35     8042.21      103.14          0.0  2015.0  Albany
# 3   72.58     5811.16     5677.40      133.76          0.0  2015.0  Albany
# 4   75.78     6183.95     5986.26      197.69          0.0  2015.0  Albany
#
#    month
# 0     12
# 1     12
# 2     12
# 3      6
# 4     11

# %%
df_av.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1517 entries, 0 to 1516
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1517 non-null   float64
#  1   Date          1517 non-null   object
#  2   AveragePrice  1517 non-null   float64
#  3   Total Volume  1517 non-null   float64
#  4   4046          1517 non-null   float64
#  5   4225          1517 non-null   float64
#  6   4770          1517 non-null   float64
#  7   Total Bags    1517 non-null   float64
#  8   Small Bags    1517 non-null   float64
#  9   Large Bags    1517 non-null   float64
#  10  XLarge Bags   1517 non-null   float64
#  11  type          1517 non-null   object
#  12  year          1517 non-null   float64
#  13  region        1517 non-null   object
#  14  month         1517 non-null   int64
# dtypes: float64(11), int64(1), object(3)
# memory usage: 189.6+ KB

# %%
df_av.shape
# Out:
# (1517, 15)

# %%
#checking null values
df_av.isnull().sum()
#no null values
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# month           0
# dtype: int64

# %%
df_av.region.value_counts()
#finding the count on the basis of region
#we caan find that california has the highest sale and LosAngeles has only 3
# Out:
# California             76
# Albany                 67
# Boise                  65
# BaltimoreWashington    65
# Boston                 62
# Atlanta                54
# PhoenixTucson          52
# BuffaloRochester       51
# Spokane                49
# Columbus               47
# NewYork                44
# Jacksonville           41
# Detroit                40
# SouthCentral           39
# SanDiego               38
# West                   36
# Louisville             34
# Tampa                  34
# Charlotte              31
# Portland               30
# NorthernNewEngland     29
# Houston                29
# WestTexNewMexico       27
# TotalUS                25
# Nashville              25
# Denver                 24
# SouthCarolina          24
# Chicago                23
# GrandRapids            23
# Pittsburgh             22
# RichmondNorfolk        21
# Orlando                21
# Syracuse               19
# HarrisburgScranton     19
# GreatLakes             18
# ...

# %%
#finding the count in the region column
df_av.type.value_counts()

#only one type of avocado i.e. conventional
# Out:
# conventional    1517
# Name: type, dtype: int64

# %%
df_av.year.value_counts()
# Out:
# 2015.0    1270
# 2016.0     247
# Name: year, dtype: int64

# %%
df_av.describe()
# Out:
#         Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  1517.000000   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03
# mean     26.995386      1.074990  1.601879e+06  6.464387e+05  6.114375e+05
# std      14.848287      0.188891  4.433143e+06  1.947614e+06  1.672906e+06
# min       0.000000      0.490000  3.875074e+04  4.677200e+02  1.783770e+03
# 25%      14.000000      0.980000  1.474700e+05  2.040034e+04  4.147606e+04
# 50%      29.000000      1.080000  4.027919e+05  8.175117e+04  1.186649e+05
# 75%      39.000000      1.190000  9.819751e+05  3.775785e+05  4.851503e+05
# max      51.000000      1.680000  4.465546e+07  1.893304e+07  1.895648e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000
# mean   5.040550e+04  2.935974e+05  2.487736e+05  4.264205e+04    2181.771074
# ...

# %%
plt.figure(figsize=(12,5))
sns.distplot(df_av["AveragePrice"], color = 'b')
#plotting average price ,highest frequency is for between 1-1.2 and mostly concentrated in that range
# Out:
# C:\Users\Preeti kumari\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(50,20))
plt.xlabel("month", fontsize=40)
plt.ylabel("AveragePrice", fontsize=40)
plt.xticks(rotation=90,fontsize=30)
plt.yticks(rotation=0,fontsize=30)
sns.barplot(x="month",y="AveragePrice",data=df_av)
#plotting the average price on the basis of month and we can observe it is almost same for all the months so we can drop this coluumn later

# %%
plt.figure(figsize=(50,20))
plt.xlabel("Region", fontsize=40)
plt.ylabel("AveragePrice", fontsize=40)
plt.xticks(rotation=90,fontsize=30)
plt.yticks(rotation=0,fontsize=25)
sns.barplot(x="region",y="AveragePrice",hue="year",data=df_av)
#plotting the graph by taking x axis as region,y axis as average price and hue as year

# %% [markdown]
# Observation:
# 1.For the year 2016, Charlotte and Albany has the highest average price.
# 2.For the year 2015,Syracuse has maximum average price

# %% [markdown]
# # Graphing three PLU's and region

# %%
plt.figure(figsize=(50,20))
plt.xlabel("Region", fontsize=40)
plt.ylabel("4046", fontsize=40)
plt.xticks(rotation=90,fontsize=30)
plt.yticks(rotation=0,fontsize=25)
sns.barplot(x="region",y="4046",data=df_av)

# %%
plt.figure(figsize=(50,20))
plt.xlabel("Region", fontsize=40)
plt.ylabel("4225", fontsize=40)
plt.xticks(rotation=90,fontsize=30)
plt.yticks(rotation=0,fontsize=25)
sns.barplot(x="region",y="4225",data=df_av)

# %%
plt.figure(figsize=(50,20))
plt.xlabel("Region", fontsize=40)
plt.ylabel("4770", fontsize=40)
plt.xticks(rotation=90,fontsize=30)
plt.yticks(rotation=0,fontsize=25)
sns.barplot(x="region",y="4770",data=df_av)

# %% [markdown]
# Observation
#
# 1.4046-Heighest in Total US and lowest in Albany
# 2.4225-Heighest in Total Us and lowest in Boise
# 3.4770-Heighest in Total Us and lowest in Tampa

# %%
plt.figure(figsize=(50,20))
plt.xlabel("Region", fontsize=40)
plt.ylabel("Total Bags", fontsize=40)
plt.xticks(rotation=90,fontsize=30)
plt.yticks(rotation=0,fontsize=25)
sns.barplot(x="region",y="Total Bags",data=df_av)

# %% [markdown]
# From the above we can see the heighest number of bags are in Total USA

# %%
plt.scatter(x=df_av["Total Bags"],y=df_av["Total Volume"])
plt.xlabel("Total Bags", fontsize=15)
plt.ylabel("Total Volume", fontsize=15)
#there is positive correlation between average price and total bags
#average price is similar till 3 and then increased after 5 till 7
# Out:
# Text(0, 0.5, 'Total Volume')

# %%
grouped = df_av.groupby('region').sum().reset_index()
grouped.sort_values('AveragePrice', ascending=False)
#sorting region by average price
# Out:
#                  region  Unnamed: 0  AveragePrice  Total Volume          4046  \
# 0                Albany      1431.0         82.99  5.111443e+06  1.160478e+05
# 6            California      1986.0         80.25  4.586810e+08  1.831613e+08
# 2   BaltimoreWashington      1768.0         75.46  5.249687e+07  3.811506e+06
# 4                Boston      1999.0         74.74  3.431443e+07  4.619336e+05
# 5      BuffaloRochester      1247.0         66.38  6.741403e+06  8.039075e+04
# 3                 Boise      1782.0         63.37  5.268001e+06  2.781901e+06
# 26              NewYork       946.0         54.94  5.997083e+07  8.997909e+05
# 1               Atlanta      1341.0         54.65  2.525241e+07  1.736038e+07
# 44              Spokane      1176.0         53.71  3.782042e+06  1.472627e+06
# 9              Columbus      1081.0         47.59  6.850740e+06  3.295324e+06
# 19         Jacksonville       820.0         45.66  5.658909e+06  3.684377e+06
# ...

# %%
df_av.drop(columns=["Unnamed: 0","Date","type","month"],axis=1,inplace=True)
# Out:
# C:\Users\Preeti kumari\anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# Encoding the  column region

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
df_av["region"] = labelencoder.fit_transform(df_av["region"])
# Out:
# <ipython-input-106-44a3d9b2bc31>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_av["region"] = labelencoder.fit_transform(df_av["region"])

# %%
df=df_av.copy()

# %% [markdown]
# # Region Classification

# %%
corr_matrix=df_av.corr()
corr_matrix["region"].sort_values(ascending=False)
#dropping columns with less correlation
# Out:
# region          1.000000
# Large Bags      0.297452
# 4046            0.269481
# Total Volume    0.236579
# 4225            0.215733
# Total Bags      0.190001
# Small Bags      0.168650
# 4770            0.138092
# XLarge Bags    -0.046144
# AveragePrice   -0.229408
# year           -0.470472
# Name: region, dtype: float64

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df_av.corr(), vmax=0.6, square=True, annot=True)
#positive correlation

# %%
df_av.skew()
#finding skewness
# Out:
# AveragePrice   -0.109444
# Total Volume    6.200138
# 4046            6.051830
# 4225            6.394926
# 4770            5.405164
# Total Bags      5.366378
# Small Bags      5.355185
# Large Bags      5.144495
# XLarge Bags     5.775077
# year            1.828332
# region          0.288146
# dtype: float64

# %%
df_av.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags    year  region
# 0     8603.62       93.25          0.0  2015.0       0
# 1     9408.07       97.49          0.0  2015.0       0
# 2     8042.21      103.14          0.0  2015.0       0
# 3     5677.40      133.76          0.0  2015.0       0
# 4     5986.26      197.69          0.0  2015.0       0

# %%
#removing skewness
import numpy as np
for col in df_av.columns:
    if df_av.skew().loc[col]>1.5:
        df_av[col]=np.log1p(df_av[col])
# Out:
# <ipython-input-112-ba2a1ac63d06>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_av[col]=np.log1p(df_av[col])

# %%
df_av.skew()
# Out:
# AveragePrice   -0.109444
# Total Volume    0.667468
# 4046           -0.160268
# 4225            0.184436
# 4770           -0.355508
# Total Bags      0.695502
# Small Bags      0.713843
# Large Bags     -0.912766
# XLarge Bags     0.783913
# year            1.828332
# region          0.288146
# dtype: float64

# %%
from scipy import stats
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(df_av))
threshold=3
df_av =df_av[(z < 3).all(axis=1)]
#removing outliers
print(df_av.shape)
#printing the shape after removing outliers
# Out:
# (1502, 11)

# %%
x_re=df_av.drop("region",axis=1)
y=df_av["region"]
#splitting into input and output part

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(x_re)
x=sc.transform(x_re)
x=pd.DataFrame(x,columns=x_re.columns)
#scaling the columns of

# %%
#feature importance
from sklearn.ensemble import ExtraTreesRegressor
model=ExtraTreesRegressor()
model.fit(x,y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [0.04192683 0.05685968 0.13098245 0.10265456 0.11072038 0.0776996
#  0.06583399 0.13336562 0.06097882 0.21897807]

# %%
feat_importance=pd.Series(model.feature_importances_,index=x.columns)
feat_importance.plot(kind="barh")
plt.show()
#this will helpus to find the important features required for the model

# %%
from sklearn.ensemble import RandomForestClassifier

from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.metrics import f1_score
from sklearn import svm  
from sklearn.metrics import precision_score
from sklearn.model_selection import cross_val_score

from sklearn.metrics import recall_score
from sklearn.model_selection import train_test_split

# %%
model=[DecisionTreeClassifier(),svm.SVC(),RandomForestClassifier(),KNeighborsClassifier()]
for m in model:
    m.fit(x_train,y_train)
    predm=m.predict(x_test)
    print("Score of",m,"is",accuracy_score(y_test,predm))
    print("Cross val score:",cross_val_score(m,x,y,cv=3,scoring="accuracy").mean())
    print("\n")
# Out:
# Score of DecisionTreeClassifier() is 0.8737541528239202
# Cross val score: 0.7157325349301398
#
#
# Score of SVC() is 0.9136212624584718
# Cross val score: 0.7909407850964737
#
#
# Score of RandomForestClassifier() is 0.9601328903654485
# Cross val score: 0.8522182302062542
#
#
# Score of KNeighborsClassifier() is 0.9435215946843853
# Cross val score: 0.819575515635396

# %% [markdown]
# Observation
#  1.The cross val square and the accuracy has very less difference so there is no overfitting
#  2.Considering KNeighborsClassifier to evalute the model now as it is not very high and not very low

# %%
from sklearn.model_selection import GridSearchCV
model=KNeighborsClassifier()
params = {'n_neighbors':[5,6,7,8,9,10],
          'leaf_size':[1,2,3,5],
          'weights':['uniform', 'distance'],
          'algorithm':['auto', 'ball_tree','kd_tree','brute'],
          'n_jobs':[-1]}
model1 = GridSearchCV(model, param_grid=params, n_jobs=1)
model1.fit(x,y)
print("Best Hyper Parameters:\n",model1.best_params_)
#hyperparameter tuning for better score
# Out:
# C:\Users\Preeti kumari\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:670: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
# Best Hyper Parameters:
#  {'algorithm': 'auto', 'leaf_size': 1, 'n_jobs': -1, 'n_neighbors': 5, 'weights': 'distance'}

# %%
#Now using the hyper parameters 
knn=KNeighborsClassifier(leaf_size= 1, n_jobs= -1, n_neighbors= 5, weights= 'distance')
knn.fit(x_train,y_train)
ypred=knn.predict(x_test)
print("Accuracy score is:",accuracy_score(y_test,ypred))
print("F1 score is:",f1_score(y_test,ypred,average='macro'))
print('Precision score is:',precision_score(y_test, ypred, average='macro'))
print("Recall score is:",recall_score(y_test,ypred,average="macro"))
# Out:
# Accuracy score is: 0.9534883720930233
# F1 score is: 0.9416492317750899
# Precision score is: 0.9479357864357865
# Recall score is: 0.9450317460317461

# %%
df_result=pd.DataFrame(ypred)
df_result
# Out:
#       0
# 0    44
# 1    50
# 2     8
# 3     6
# 4    16
# ..   ..
# 296  22
# 297  18
# 298  22
# 299  37
# 300   5
#
# [301 rows x 1 columns]

# %%
df_result.to_csv('Output.csv')

# %%
import joblib
joblib.dump(knn,"region.pkl")
# Out:
# ['region.pkl']

# %% [markdown]
# # For Average Price

# %%
corr_matrix_price=df.corr()
corr_matrix_price["AveragePrice"].sort_values(ascending=False)
#mostly negative correlation with all the attributes
# Out:
# AveragePrice    1.000000
# year            0.178683
# XLarge Bags    -0.048284
# 4225           -0.092084
# Small Bags     -0.097682
# 4770           -0.100567
# Total Bags     -0.111597
# Total Volume   -0.140470
# Large Bags     -0.177480
# 4046           -0.190096
# region         -0.229408
# Name: AveragePrice, dtype: float64

# %% [markdown]
# Plotting different attributes and shows there relationship with the output(AveragePrice)

# %%
#1.
plt.scatter(x=df_av["AveragePrice"],y=df_av["Total Volume"])
plt.xlabel("AveragePrice", fontsize=15)
plt.ylabel("Total Volume", fontsize=15)
# Out:
# Text(0, 0.5, 'Total Volume')

# %%
#2
plt.scatter(x=df_av["AveragePrice"],y=df_av["4046"])
plt.xlabel("AveragePrice", fontsize=15)
plt.ylabel("4046", fontsize=15)
# Out:
# Text(0, 0.5, '4046')

# %%
plt.scatter(x=df_av["AveragePrice"],y=df_av["XLarge Bags"])
plt.xlabel("AveragePrice", fontsize=15)
plt.ylabel("XLarge Bags" ,fontsize=15)
# Out:
# Text(0, 0.5, 'XLarge Bags')

# %% [markdown]
# Observation:
#
# 1.From the first graph we can see there is some negative correlation bewtween average price and total volume.
#
# 2.From the second graph we can see high negative correlation between plu-4045 and average price
#
# 3.From the third graph we are unable to understand any such relation and also he coefficient is also very less.

# %%
x_p=df.drop(columns=["AveragePrice","XLarge Bags","Total Bags","4225","Large Bags"],axis=1)
y_p=df["AveragePrice"]
#splitting data into input and output also dropping few columns with less correlation

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(x_p)
x_ap=sc.transform(x_p)
x_ap=pd.DataFrame(x_ap,columns=x_p.columns)
#scaling the columns of x_ap

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test=train_test_split(x_ap,y_p,random_state = 42,test_size=0.20)

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
model=[LinearRegression(),DecisionTreeRegressor(),KNeighborsRegressor(),SVR(),Lasso(),Ridge(),ElasticNet()]
for m in model:
    m.fit(X_train,Y_train)
    print("score of ",m, "is:",m.score(X_train,Y_train))
    predm=m.predict(X_test)
    print("ERROR:")
    print(" Mean absolute error:", mean_absolute_error(Y_test,predm))
    print("Mean squared error:",mean_squared_error(Y_test,predm))
    print("r2 score :",r2_score(Y_test,predm))
    print("\n")
# Out:
# score of  LinearRegression() is: 0.14274353523928696
# ERROR:
#  Mean absolute error: 0.13646318693740772
# Mean squared error: 0.030526005382307483
# r2 score : 0.13013321931242505
#
#
# score of  DecisionTreeRegressor() is: 1.0
# ERROR:
#  Mean absolute error: 0.07736842105263157
# Mean squared error: 0.012412499999999998
# r2 score : 0.6462943224945356
#
#
# score of  KNeighborsRegressor() is: 0.8868224909604402
# ERROR:
#  Mean absolute error: 0.058019736842105256
# Mean squared error: 0.006203460526315788
# r2 score : 0.82322664988206
#
#
# score of  SVR() is: 0.4801640107541132
# ERROR:
#  Mean absolute error: 0.10598890270680862
# Mean squared error: 0.01947239321545613
# r2 score : 0.44511613011675966
#
#
# score of  Lasso() is: 0.0
# ERROR:
#  Mean absolute error: 0.14404480518071766
# Mean squared error: 0.03524373407766401
# r2 score : -0.004302826969794671
#
#
# score of  Ridge() is: 0.1419764163828625
# ERROR:
#  Mean absolute error: 0.13629824615595323
# ...

# %% [markdown]
# Observation:
# Selecting KNeighborsRegressor for predicting the average price as the score is high,however r2 score is high for SVC but the error and accuracy is better for KNeighborsRegressor.

# %%
from sklearn.model_selection import GridSearchCV
model=KNeighborsRegressor()
params = {'n_neighbors':[5,6,7,8,9,10],
          'leaf_size':[1,2,3,5],
          'weights':['uniform', 'distance'],
          'algorithm':['auto', 'ball_tree','kd_tree','brute'],
          'n_jobs':[-1]}
model1 = GridSearchCV(model, param_grid=params, n_jobs=1)
model1.fit(X_train,Y_train)
print("Best Hyper Parameters:\n",model1.best_params_)
# Out:
# Best Hyper Parameters:
#  {'algorithm': 'auto', 'leaf_size': 1, 'n_jobs': -1, 'n_neighbors': 5, 'weights': 'distance'}

# %% [markdown]
# Boosting the score

# %%
knn=KNeighborsClassifier(algorithm= 'auto', leaf_size= 1, n_jobs= -1, n_neighbors= 5, weights= 'distance')
knn.fit(x_train,y_train)
ypred=knn.predict(x_test)
print("Accuracy score is:",accuracy_score(y_test,ypred))
print("F1 score is:",f1_score(y_test,ypred,average='macro'))
print('Precision score is:',precision_score(y_test, ypred, average='macro'))
print("Recall score is:",recall_score(y_test,ypred,average="macro"))
# Out:
# Accuracy score is: 0.9534883720930233
# F1 score is: 0.9416492317750899
# Precision score is: 0.9479357864357865
# Recall score is: 0.9450317460317461

# %%
from sklearn.ensemble import AdaBoostRegressor
knn_r=KNeighborsRegressor()
adb=AdaBoostRegressor(base_estimator=knn_r,n_estimators=6,learning_rate=1,random_state=42)
adb.fit(x_train,y_train)
print("Score:",adb.score(x_train,y_train))
predab=adb.predict(x_test)
print("ERROR:")
print(" Mean absolute error:", mean_absolute_error(y_test,predab))
print("Mean squared error:",mean_squared_error(y_test,predab))
print("r2 score :",r2_score(y_test,predab))
# Out:
# Score: 0.9893177580668203
# ERROR:
#  Mean absolute error: 0.9401993355481728
# Mean squared error: 10.400930232558139
# r2 score : 0.957579736401729

# %% [markdown]
# Ada Boost regressor is working well as the score is also nice and r2 score is also good
# So we save AdaBoostRegressor as our final model.

# %%
df_average_price=pd.DataFrame(predab)
df_average_price
# Out:
#         0
# 0    44.0
# 1    46.2
# 2     8.0
# 3     6.0
# 4    16.0
# ..    ...
# 296  22.0
# 297  19.6
# 298  22.0
# 299  37.0
# 300   3.0
#
# [301 rows x 1 columns]

# %%
df_average_price.to_csv('Output average price.csv')

# %%
import joblib
joblib.dump(adb,"average price.pkl")
# Out:
# ['average price.pkl']
